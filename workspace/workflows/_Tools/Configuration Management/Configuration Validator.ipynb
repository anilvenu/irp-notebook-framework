# %% [markdown]
# # Configuration Validator
#
# This notebook validates Excel configuration files and optionally loads them to the database.
#
# **You can do the following with this tool:**
# - Validate configuration Excel file (without registering them)
# - View detailed validation results per sheet
# - Optionally register validated configuration to database (not recommended)
# - Preview transformer outputs without creating batches and jobs
# - Run any or all transformers to see job configurations

# %%
# Import required modules
from helpers import configuration, ux, cycle
from helpers.configuration import ConfigurationError
from helpers.database import execute_query
import pandas as pd
from pathlib import Path
import json

# %% [markdown]
# ## Check Active Cycle

# %%
# Get and display active cycle
ux.header("Active Cycle Status")

active_cycle = cycle.get_active_cycle()
if active_cycle:
    ux.success(f"Active Cycle: {active_cycle['cycle_name']}")
    cycle_id = active_cycle['id']
    
    # Display cycle info
    info_data = [
        ['Cycle ID', cycle_id],
        ['Cycle Name', active_cycle['cycle_name']],
        ['Status', active_cycle['status']],
        ['Created', str(active_cycle['created_ts'])]
    ]
    ux.table(info_data, headers=['Property', 'Value'])
else:
    ux.error("No active cycle found. Please create a cycle first.")
    raise Exception("No active cycle")
# Out:
# <h3 style='font-weight:bold; font-size:1.1em; color:#111;'>Active Cycle Status</h3>
# <span style='color:green; font-weight:bold;'>Active Cycle: Analysis-2025-Q4-v2</span>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Property</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Cycle ID</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Cycle Name</td>
#       <td>Analysis-2025-Q4-v2</td>
#     </tr>
#     <tr>
#       <td>Status</td>
#       <td>ACTIVE</td>
#     </tr>
#     <tr>
#       <td>Created</td>
#       <td>2025-11-06 16:33:00.112120+00:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Select Configuration File

# %%
# File selection with validation
ux.subheader("Configuration File Selection")

def validate_excel_path(path_str):
    """Validate that path exists and is an Excel file"""
    if not path_str.strip():
        return False
    path = Path(path_str)
    if not path.exists():
        print(f"File not found: {path_str}")
        return False
    if path.suffix.lower() not in ['.xlsx', '.xls']:
        print("File must be an Excel file (.xlsx or .xls)")
        return False
    return True

excel_path = ux.text_input(
    "Enter path to Excel configuration file",
    placeholder="/home/jovyan/workspace/tests/files/valid_excel_configuration.xlsx",
    validation=validate_excel_path
)

if excel_path is None:
    ux.error("File selection cancelled")
    raise Exception("Cancelled")

# Display file info
file_path = Path(excel_path)
file_size_mb = file_path.stat().st_size / (1024 * 1024)
file_data = [
    ['File Path', str(file_path.absolute())],
    ['File Name', file_path.name],
    ['File Size', f"{file_size_mb:.2f} MB"],
    ['Last Modified', str(pd.Timestamp.fromtimestamp(file_path.stat().st_mtime))]
]
ux.table(file_data, headers=['Property', 'Value'])
ux.success("File found and ready for validation")
# Out:
# <h4 style='font-weight:bold; font-size:1.0em; color:#333;'>Configuration File Selection</h4>
# Enter path to Excel configuration file (e.g., /home/jovyan/workspace/tests/files/valid_excel_configuration.xlsx) (enter 'cancel' to stop)
# >  /home/jovyan/workspace/tests/files/valid_excel_configuration.xlsx
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Property</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>File Path</td>
#       <td>/home/jovyan/workspace/tests/files/valid_excel_configuration.xlsx</td>
#     </tr>
#     <tr>
#       <td>File Name</td>
#       <td>valid_excel_configuration.xlsx</td>
#     </tr>
#     <tr>
#       <td>File Size</td>
#       <td>0.07 MB</td>
#     </tr>
#     <tr>
#       <td>Last Modified</td>
#       <td>2025-11-04 18:07:52.589818</td>
#     </tr>
#   </tbody>
# </table>
# <span style='color:green; font-weight:bold;'>File found and ready for validation</span>

# %% [markdown]
# ## Validate Configuration (Preview Mode)

# %%
# Validate configuration without loading to database
ux.header("Configuration Validation")

try:
    validation_result = configuration.validate_configuration_file(
        cycle_id=cycle_id,
        excel_config_path=excel_path
    )
    
    if validation_result['validation_passed']:
        ux.success("✓ All validation checks passed!")
    else:
        ux.warning("⚠ Validation completed with warnings/errors")
    
    # Store for later use
    config_data = validation_result['configuration_data']
    validation_results = config_data.get('_validation', {})
    
except ConfigurationError as e:
    ux.error(f"Validation failed: {str(e)}")
    raise
# Out:
# <h3 style='font-weight:bold; font-size:1.1em; color:#111;'>Configuration Validation</h3>
# <span style='color:green; font-weight:bold;'>✓ All validation checks passed!</span>

# %% [markdown]
# ### Validation Results Summary

# %%
# Display validation summary per sheet
ux.subheader("Sheet Validation Summary")

summary_data = []
for sheet_name, result in validation_results.items():
    if sheet_name == '_cross_sheet':
        continue
    
    status = result.get('status', 'UNKNOWN')
    error_count = len(result.get('errors', []))
    warning_count = len(result.get('warnings', []))
    row_count = result.get('row_count', 0)
    
    # Status indicator
    if status == 'SUCCESS':
        status_icon = '✓'
    elif status == 'ERROR':
        status_icon = '✗'
    else:
        status_icon = '?'
    
    summary_data.append([
        f"{status_icon} {sheet_name}",
        status,
        row_count,
        error_count,
        warning_count
    ])

summary_df = pd.DataFrame(summary_data, columns=['Sheet', 'Status', 'Rows', 'Errors', 'Warnings'])
ux.dataframe(summary_df)

# Check for cross-sheet validation
if '_cross_sheet' in validation_results:
    cross_result = validation_results['_cross_sheet']
    if cross_result['status'] == 'ERROR':
        ux.error(f"✗ Cross-Sheet Validation: {len(cross_result['errors'])} errors")
    else:
        ux.success("✓ Cross-Sheet Validation: Passed")
# Out:
# <h4 style='font-weight:bold; font-size:1.0em; color:#333;'>Sheet Validation Summary</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sheet</th>
#       <th>Status</th>
#       <th>Rows</th>
#       <th>Errors</th>
#       <th>Warnings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>✓ Metadata</td>
#       <td>SUCCESS</td>
#       <td>11</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ Databases</td>
#       <td>SUCCESS</td>
#       <td>7</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ Portfolios</td>
#       <td>SUCCESS</td>
#       <td>70</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ Reinsurance Treaties</td>
#       <td>SUCCESS</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ GeoHaz Thresholds</td>
#       <td>SUCCESS</td>
#       <td>121</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ Analysis Table</td>
#       <td>SUCCESS</td>
#       <td>93</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ Groupings</td>
#       <td>SUCCESS</td>
#       <td>96</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ Products and Perils</td>
#       <td>SUCCESS</td>
#       <td>264</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>✓ Moody's Reference Data</td>
#       <td>SUCCESS</td>
#       <td>75</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Detailed Validation Results (Errors & Warnings)

# %%
# Show detailed errors and warnings
ux.subheader("Detailed Validation Results")

has_issues = False

for sheet_name, result in validation_results.items():
    errors = result.get('errors', [])
    warnings = result.get('warnings', [])
    
    if errors or warnings:
        has_issues = True
        print(f"\n{'='*60}")
        print(f"Sheet: {sheet_name}")
        print(f"{'='*60}")
        
        if errors:
            ux.error(f"Errors ({len(errors)}):")
            for i, error in enumerate(errors, 1):
                print(f"  {i}. {error}")
        
        if warnings:
            ux.warning(f"Warnings ({len(warnings)}):")
            for i, warning in enumerate(warnings, 1):
                print(f"  {i}. {warning}")

if not has_issues:
    ux.success("No errors or warnings found!")
# Out:
# <h4 style='font-weight:bold; font-size:1.0em; color:#333;'>Detailed Validation Results</h4>
# <span style='color:green; font-weight:bold;'>No errors or warnings found!</span>

# %% [markdown]
# ## Load Configuration to Database (Optional)

# %%
# Ask user if they want to load the configuration
ux.header("Load Configuration to Database")

if not validation_result['validation_passed']:
    ux.error("Cannot load configuration with validation errors. Please fix errors first.")
else:
    # Check for existing configurations
    query = "SELECT id, configuration_file_name, status FROM irp_configuration WHERE cycle_id = %s"
    existing_configs = execute_query(query, (cycle_id,))
    
    if not existing_configs.empty:
        ux.warning(f"Found {len(existing_configs)} existing configuration(s) for this cycle:")
        ux.dataframe(existing_configs)
        ux.warning("Loading a new configuration will DELETE all existing configurations for this cycle.")
    
    if ux.yes_no("Do you want to load this configuration to the database?"):
        try:
            config_id = configuration.load_configuration_file(
                cycle_id=cycle_id,
                excel_config_path=excel_path
            )
            ux.success(f"Configuration loaded successfully! Configuration ID: {config_id}")
            
            # Display loaded configuration info
            query = "SELECT id, configuration_file_name, status, created_ts FROM irp_configuration WHERE id = %s"
            config_info = execute_query(query, (config_id,))
            ux.dataframe(config_info)
            
        except ConfigurationError as e:
            ux.error(f"Failed to load configuration: {str(e)}")
    else:
        ux.info("Configuration not loaded. Validation results are still available for review.")
# Out:
# <h3 style='font-weight:bold; font-size:1.1em; color:#111;'>Load Configuration to Database</h3>
# Do you want to load this configuration to the database? (y/n):  n
# <span style='color:#005f9e;'>Configuration not loaded. Validation results are still available for review.</span>

# %% [markdown]
# ## Preview Transformer Outputs

# %% [markdown]
# ### Select Transformers to Run

# %%
# Get list of available transformers
ux.header("Transformer Preview")

if not validation_result['validation_passed']:
    ux.error("Cannot preview transformers with validation errors. Please fix errors first.")
else:
    available_transformers = configuration.get_transformer_list(include_test=False)
    
    ux.info(f"Available transformers: {len(available_transformers)}")
    
    # Display transformer options
    print("\nAvailable Transformers:")
    print("0. Run ALL transformers")
    for i, transformer in enumerate(available_transformers, 1):
        print(f"{i}. {transformer}")
    
    # Get user selection
    print("\nEnter transformer numbers (comma-separated) or 0 for all:")
    selection = input("> ").strip()
    
    # Parse selection
    selected_transformers = []
    if selection == '0':
        selected_transformers = available_transformers
        ux.success(f"Selected all {len(selected_transformers)} transformers")
    else:
        try:
            indices = [int(x.strip()) for x in selection.split(',')]
            for idx in indices:
                if 1 <= idx <= len(available_transformers):
                    selected_transformers.append(available_transformers[idx-1])
            ux.success(f"Selected {len(selected_transformers)} transformer(s)")
        except ValueError:
            ux.error("Invalid selection")
            selected_transformers = []
# Out:
# <h3 style='font-weight:bold; font-size:1.1em; color:#111;'>Transformer Preview</h3>
# <span style='color:#005f9e;'>Available transformers: 11</span>
# Available Transformers:
# 0. Run ALL transformers
# 1. EDM Creation
# 2. Portfolio Creation
# 3. MRI Import
# 4. Create Reinsurance Treaties
# 5. EDM DB Upgrade
# 6. GeoHaz
# 7. Portfolio Mapping
# 8. Analysis
# 9. Grouping
# 10. Export to RDM
# 11. Staging ETL
#
# Enter transformer numbers (comma-separated) or 0 for all:
# >  8
# <span style='color:green; font-weight:bold;'>Selected 1 transformer(s)</span>

# %% [markdown]
# ### Run Transformers and Display Results (Preview first 3)

# %%
selected_transformers
# Out:
# ['Analysis']

# %%
# Run selected transformers
if selected_transformers:
    ux.subheader("Transformer Results")
    
    transformer_results = {}
    
    for transformer_name in selected_transformers:
        print(f"\n{'='*60}")
        print(f"Transformer: {transformer_name}")
        print(f"{'='*60}")
        
        try:
            job_configs = configuration.preview_transformer_jobs(
                batch_type=transformer_name,
                configuration_data=config_data
            )
            
            transformer_results[transformer_name] = job_configs
            
            ux.success(f"Generated {len(job_configs)} job configuration(s)")
            
            # Display preview of first 3 jobs
            preview_count = min(3, len(job_configs))
            if preview_count > 0:
                print(f"\nPreview (showing first {preview_count} of {len(job_configs)} jobs):")
                for i, job_config in enumerate(job_configs[:preview_count], 1):
                    print(f"\n  Job {i}:")
                    print(json.dumps(job_config, indent=2)) 
            
            if len(job_configs) > preview_count:
                ux.info(f"... and {len(job_configs) - preview_count} more job(s)")
                
        except ConfigurationError as e:
            ux.error(f"Failed to run transformer: {str(e)}")
            transformer_results[transformer_name] = None
    
    # Summary
    print(f"\n{'='*60}")
    ux.subheader("Transformer Summary")
    summary_data = []
    total_jobs = 0
    for transformer_name, jobs in transformer_results.items():
        if jobs is not None:
            job_count = len(jobs)
            total_jobs += job_count
            summary_data.append([transformer_name, job_count, '✓'])
        else:
            summary_data.append([transformer_name, 0, '✗'])
    
    summary_df = pd.DataFrame(summary_data, columns=['Transformer', 'Job Count', 'Status'])
    ux.dataframe(summary_df)
    ux.success(f"Total jobs across all transformers: {total_jobs}")
else:
    ux.info("No transformers selected")
# Out:
# <h4 style='font-weight:bold; font-size:1.0em; color:#333;'>Transformer Results</h4>
# ============================================================
# Transformer: Analysis
# ============================================================
# <function transform_analysis at 0x75dc07de6200>
# <span style='color:green; font-weight:bold;'>Generated 93 job configuration(s)</span>
# Preview (showing first 3 of 93 jobs):
#
#   Job 1:
# {
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_CBAP",
#   "Portfolio": "CBHU",
#   "Analysis Name": "CBHU_LT",
#   "Analysis Profile": "DLM CBHU v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_CBHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }
#
#   Job 2:
# {
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_CBAP",
#   "Portfolio": "CBHU",
#   "Analysis Name": "CBHU_NT",
#   "Analysis Profile": "DLM CBHU v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_CBHU_NT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }
#
#   Job 3:
# {
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_CBAP",
#   "Portfolio": "CBEQ",
#   "Analysis Name": "CBEQ",
#   "Analysis Profile": "DLM CBEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_CBEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }
# <span style='color:#005f9e;'>... and 90 more job(s)</span>
# ============================================================
# <h4 style='font-weight:bold; font-size:1.0em; color:#333;'>Transformer Summary</h4>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Transformer</th>
#       <th>Job Count</th>
#       <th>Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Analysis</td>
#       <td>93</td>
#       <td>✓</td>
#     </tr>
#   </tbody>
# </table>
# <span style='color:green; font-weight:bold;'>Total jobs across all transformers: 93</span>

# %% [markdown]
# ### View Full Job Configuration

# %%
# Option to view full job configurations
if transformer_results and ux.yes_no("Do you want to see full job configurations?"):
    transformer_name = ux.dropdown(
        list(transformer_results.keys()),
        prompt="Select transformer to view full job configs"
    )
    
    if transformer_name and transformer_results[transformer_name]:
        jobs = transformer_results[transformer_name]
        ux.subheader(f"Full Job Configurations for: {transformer_name}")
        ux.info(f"Total jobs: {len(jobs)}")
        
        for i, job_config in enumerate(jobs, 1):
            print(f"\n{'='*60}")
            print(f"Job {i} of {len(jobs)}")
            print(f"{'='*60}")
            ux.json(job_config)
            
            # Pause after every 5 jobs
            if i % 5 == 0 and i < len(jobs):
                if not ux.yes_no(f"Continue viewing? ({len(jobs) - i} remaining)"):
                    break
else:
    ux.info("Skipped full job configuration view")
# Out:
# Do you want to see full job configurations? (y/n):  y
# Select transformer to view full job configs
# Options:
# 1. Analysis
# Enter 1-1 or 'cancel' to stop
# >  8
# Please enter a number between 1 and 1
# >  1
# <h4 style='font-weight:bold; font-size:1.0em; color:#333;'>Full Job Configurations for: Analysis</h4>
# <span style='color:#005f9e;'>Total jobs: 93</span>
# ============================================================
# Job 1 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_CBAP",
#   "Portfolio": "CBHU",
#   "Analysis Name": "CBHU_LT",
#   "Analysis Profile": "DLM CBHU v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_CBHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 2 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_CBAP",
#   "Portfolio": "CBHU",
#   "Analysis Name": "CBHU_NT",
#   "Analysis Profile": "DLM CBHU v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_CBHU_NT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 3 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_CBAP",
#   "Portfolio": "CBEQ",
#   "Analysis Name": "CBEQ",
#   "Analysis Profile": "DLM CBEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_CBEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 4 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USEQ",
#   "Portfolio": "USEQ_Clay_Homes",
#   "Analysis Name": "USEQ_Clay_Homes",
#   "Analysis Profile": "DLM USEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 5 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USEQ",
#   "Portfolio": "USEQ_Clay_21st",
#   "Analysis Name": "USEQ_Clay_21st",
#   "Analysis Profile": "DLM USEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (88 remaining) (y/n):  y
# ============================================================
# Job 6 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USEQ",
#   "Portfolio": "USEQ_CHFS",
#   "Analysis Name": "USEQ_CHFS",
#   "Analysis Profile": "DLM USEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 7 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USEQ",
#   "Portfolio": "USEQ_Condo",
#   "Analysis Name": "USEQ_Condo",
#   "Analysis Profile": "DLM USEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 8 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USEQ",
#   "Portfolio": "USEQ_Renters",
#   "Analysis Name": "USEQ_Renters",
#   "Analysis Profile": "DLM USEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 9 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USEQ",
#   "Portfolio": "USEQ_Manufactured",
#   "Analysis Name": "USEQ_Manufactured",
#   "Analysis Profile": "DLM USEQ v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USEQ",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 10 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Geico_75HIP2",
#   "Analysis Name": "USFF_Geico_75HIP2",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "Geico_2.075QS",
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (83 remaining) (y/n):  y
# ============================================================
# Job 11 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Geico_HIP1",
#   "Analysis Name": "USFF_Geico_HIP1",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 12 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Clay_Homes",
#   "Analysis Name": "USFF_Clay_Homes",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 13 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Clay_21st",
#   "Analysis Name": "USFF_Clay_21st",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 14 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Other",
#   "Analysis Name": "USFF_Other",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 15 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_CHFS",
#   "Analysis Name": "USFF_CHFS",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (78 remaining) (y/n):  y
# ============================================================
# Job 16 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Condo",
#   "Analysis Name": "USFF_Condo",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 17 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Renters",
#   "Analysis Name": "USFF_Renters",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 18 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Manufactured",
#   "Analysis Name": "USFF_Manufactured",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 19 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFF",
#   "Portfolio": "USFF_Lender_P",
#   "Analysis Name": "USFF_Lender_P",
#   "Analysis Profile": "DLM USFF v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 17.0 NA   Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFF",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 20 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFL",
#   "Portfolio": "USFL_Other_Other",
#   "Analysis Name": "USFL_Other_Other_LT",
#   "Analysis Profile": "DLM USFL (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFL_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (73 remaining) (y/n):  y
# ============================================================
# Job 21 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFL",
#   "Portfolio": "USFL_Other_Renters",
#   "Analysis Name": "USFL_Other_Renters_LT",
#   "Analysis Profile": "DLM USFL (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFL_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 22 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFL",
#   "Portfolio": "USFL_Other_Maufactu",
#   "Analysis Name": "USFL_Other_Maufactu_LT",
#   "Analysis Profile": "DLM USFL (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFL_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 23 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFL",
#   "Portfolio": "USFL_Other_Lender_P",
#   "Analysis Name": "USFL_Other_Lender_P_LT",
#   "Analysis Profile": "DLM USFL (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFL_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 24 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFL",
#   "Portfolio": "USFL_Excess",
#   "Analysis Name": "USFL_Excess_LT",
#   "Analysis Profile": "DLM USFL (65% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFL_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 25 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USFL",
#   "Portfolio": "USFL_Commercial",
#   "Analysis Name": "USFL_Commercial_LT",
#   "Analysis Profile": "DLM USFL (65% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USFL_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (68 remaining) (y/n):  y
# ============================================================
# Job 26 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Geico_75H2",
#   "Analysis Name": "USHU_Leak_Geico_75H2_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "Geico_2.075QS",
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 27 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Geico_HIP1",
#   "Analysis Name": "USHU_Leak_Geico_HIP1_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 28 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Full_Clay_Homes",
#   "Analysis Name": "USHU_Full_Clay_Homes_LT",
#   "Analysis Profile": "DLM USHU_Full (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 29 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Full_Clay_21st",
#   "Analysis Name": "USHU_Full_Clay_21st_LT",
#   "Analysis Profile": "DLM USHU_Full (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 30 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Full_Other",
#   "Analysis Name": "USHU_Full_Other_LT",
#   "Analysis Profile": "DLM USHU_Full (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (63 remaining) (y/n):  y
# ============================================================
# Job 31 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Full_Renters",
#   "Analysis Name": "USHU_Full_Renters_LT",
#   "Analysis Profile": "DLM USHU_Full (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 32 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Full_Manufact",
#   "Analysis Name": "USHU_Full_Manufact_LT",
#   "Analysis Profile": "DLM USHU_Full (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 33 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Full_Lender_P",
#   "Analysis Name": "USHU_Full_Lender_P_LT",
#   "Analysis Profile": "DLM USHU_Full (85% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 34 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Clay_Homes",
#   "Analysis Name": "USHU_Leak_Clay_Homes_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 35 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Clay_21st",
#   "Analysis Name": "USHU_Leak_Clay_21st_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (58 remaining) (y/n):  y
# ============================================================
# Job 36 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Other",
#   "Analysis Name": "USHU_Leak_Other_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 37 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_CHFS",
#   "Analysis Name": "USHU_Leak_CHFS_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 38 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Condo",
#   "Analysis Name": "USHU_Leak_Condo_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 39 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Renters",
#   "Analysis Name": "USHU_Leak_Renters_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 40 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Manufact",
#   "Analysis Name": "USHU_Leak_Manufact_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (53 remaining) (y/n):  y
# ============================================================
# Job 41 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Lender_P",
#   "Analysis Name": "USHU_Leak_Lender_P_LT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Historical Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_LT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 42 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Clay_Homes",
#   "Analysis Name": "USST_Clay_Homes_High_Frq",
#   "Analysis Profile": "DLM USST High Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 43 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
# ...
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_NT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 80 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Condo",
#   "Analysis Name": "USHU_Leak_Condo_NT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_NT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (13 remaining) (y/n):  y
# ============================================================
# Job 81 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Renters",
#   "Analysis Name": "USHU_Leak_Renters_NT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_NT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 82 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Manufact",
#   "Analysis Name": "USHU_Leak_Manufact_NT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_NT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 83 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USHU",
#   "Portfolio": "USHU_Leak_Lender_P",
#   "Analysis Name": "USHU_Leak_Lender_P_NT",
#   "Analysis Profile": "DLM USHU_Leak (9% SS) v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2023 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USHU_NT",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 84 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Clay_Homes",
#   "Analysis Name": "USST_Clay_Homes_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 85 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Clay_21st",
#   "Analysis Name": "USST_Clay_21st_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": null,
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (8 remaining) (y/n):  y
# ============================================================
# Job 86 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Other",
#   "Analysis Name": "USST_Other_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 87 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_CHFS",
#   "Analysis Name": "USST_CHFS_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 88 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Condo",
#   "Analysis Name": "USST_Condo_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 89 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Renters",
#   "Analysis Name": "USST_Renters_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 90 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Manufactured",
#   "Analysis Name": "USST_Manufactured_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# Continue viewing? (3 remaining) (y/n):  y
# ============================================================
# Job 91 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Geico_75HIP2",
#   "Analysis Name": "USST_Geico_75HIP2_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "Geico_2.075QS",
#   "Reinsurance Treaty 2": null,
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 92 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Geico_HIP1",
#   "Analysis Name": "USST_Geico_HIP1_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>
# ============================================================
# Job 93 of 93
# ============================================================
# <pre>{
#   "Metadata": {
#     "Current Date Value": "202503",
#     "EDM Data Version": "23.0.0",
#     "Geocode Version": "23.0.0",
#     "Hazard Version": "23.0.0",
#     "DLM Model Version": 23,
#     "Validate DLM Model Versions?": "Y",
#     "Wildfire HD Model Version": 2,
#     "SCS HD Model Version": 1,
#     "Inland Flood HD Model Version": 1.2,
#     "Validate HD Model Versions?": "Y",
#     "Export RDM Name": "RMS_RDM_202503_QEM_USAP"
#   },
#   "Database": "RMS_EDM_202503_Quarterly_USST",
#   "Portfolio": "USST_Lender_P",
#   "Analysis Name": "USST_Lender_P_Low_Frq",
#   "Analysis Profile": "DLM USST Low Frq v23",
#   "Output Profile": "Modeling_Output_Profile",
#   "Event Rate": "RMS 2013 Stochastic Event Rates",
#   "Reinsurance Treaty 1": "XPR_1_95",
#   "Reinsurance Treaty 2": "XPR_1_100",
#   "Reinsurance Treaty 3": null,
#   "Reinsurance Treaty 4": null,
#   "Reinsurance Treaty 5": null,
#   "Tag 1": "202503_Quarterly_USST",
#   "Tag 2": null,
#   "Tag 3": null,
#   "Tag 4": null,
#   "Tag 5": null
# }</pre>

# %% [markdown]
# ## Summary
#
# This notebook completed the following:
# - ✓ Validated configuration file structure and data
# - ✓ Displayed validation results per sheet
# - ✓ Optionally loaded configuration to database
# - ✓ Previewed transformer outputs without creating batches
#
# **Next Steps:**
# - To create batches and jobs, use the batch management notebooks
# - To submit jobs, use the workflow execution notebooks

# %% [markdown]
# ---
