# %% [markdown]
# ## 1) Validate Portfolio Mapping SQL Scripts

# %% [markdown]
# ## 2) Apply Parameters on Portfolio Mapping SQL Scripts

# %% [markdown]
# ## 3) Execute Portfolio Mapping

# %% [markdown]
# ## 4) Review Data Creation Report
