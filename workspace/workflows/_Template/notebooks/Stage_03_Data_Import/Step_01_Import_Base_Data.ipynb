# %% [markdown]
# ## 1) Create EDMs on Moodys Risk Modeler

# %% [markdown]
# ## 2) Create Base Portfolios

# %% [markdown]
# ## 3) Populate Base Portfolios via MRI Import

# %% [markdown]
# ## 4) Create Reinsurance Treaties
